# %%
# Employee Salary Predictions using adult.csv
# Load your library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("adult 3.csv")

# %%
data
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# 1      Married-civ-spouse    Farming-fishing      Husband  White    Male
# 2      Married-civ-spouse    Protective-serv      Husband  White    Male
# 3      Married-civ-spouse  Machine-op-inspct      Husband  Black    Male
# 4           Never-married                  ?    Own-child  White  Female
# ...                   ...                ...          ...    ...     ...
# 48837  Married-civ-spouse       Tech-support         Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 48839             Widowed       Adm-clerical    Unmarried  White  Female
# 48840       Never-married       Adm-clerical    Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 0                 0             0              40  United-States  <=50K
# 1                 0             0              50  United-States  <=50K
# 2                 0             0              40  United-States   >50K
# 3              7688             0              40  United-States   >50K
# 4                 0             0              30  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 48837             0             0              38  United-States  <=50K
# 48838             0             0              40  United-States   >50K
# 48839             0             0              40  United-States  <=50K
# 48840             0             0              20  United-States  <=50K
# 48841         15024             0              40  United-States   >50K
#
# [48842 rows x 15 columns]

# %%
data.shape
# Out:
# (48842, 15)

# %%
data.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# 0              40  United-States  <=50K
# 1              50  United-States  <=50K
# 2              40  United-States   >50K
# 3              40  United-States   >50K
# 4              30  United-States  <=50K

# %%
data.tail()
# Out:
#        age     workclass  fnlwgt   education  educational-num  \
# 48837   27       Private  257302  Assoc-acdm               12
# 48838   40       Private  154374     HS-grad                9
# 48839   58       Private  151910     HS-grad                9
# 48840   22       Private  201490     HS-grad                9
# 48841   52  Self-emp-inc  287927     HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 48837  Married-civ-spouse       Tech-support         Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 48839             Widowed       Adm-clerical    Unmarried  White  Female
# 48840       Never-married       Adm-clerical    Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 48837             0             0              38  United-States  <=50K
# 48838             0             0              40  United-States   >50K
# 48839             0             0              40  United-States  <=50K
# 48840             0             0              20  United-States  <=50K
# 48841         15024             0              40  United-States   >50K

# %%
# finding null values
data.isna()
# Out:
#          age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0      False      False   False      False            False           False
# 1      False      False   False      False            False           False
# 2      False      False   False      False            False           False
# 3      False      False   False      False            False           False
# 4      False      False   False      False            False           False
# ...      ...        ...     ...        ...              ...             ...
# 48837  False      False   False      False            False           False
# 48838  False      False   False      False            False           False
# 48839  False      False   False      False            False           False
# 48840  False      False   False      False            False           False
# 48841  False      False   False      False            False           False
#
#        occupation  relationship   race  gender  capital-gain  capital-loss  \
# 0           False         False  False   False         False         False
# 1           False         False  False   False         False         False
# 2           False         False  False   False         False         False
# 3           False         False  False   False         False         False
# 4           False         False  False   False         False         False
# ...           ...           ...    ...     ...           ...           ...
# 48837       False         False  False   False         False         False
# 48838       False         False  False   False         False         False
# 48839       False         False  False   False         False         False
# 48840       False         False  False   False         False         False
# 48841       False         False  False   False         False         False
#
#        hours-per-week  native-country  income
# 0               False           False   False
# 1               False           False   False
# 2               False           False   False
# 3               False           False   False
# 4               False           False   False
# ...               ...             ...     ...
# 48837           False           False   False
# 48838           False           False   False
# 48839           False           False   False
# 48840           False           False   False
# 48841           False           False   False
#
# [48842 rows x 15 columns]

# %%
data.isna().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
data.occupation.value_counts()
# Out:
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# ?                    2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: occupation, dtype: int64

# %%
data.gender.value_counts()
# Out:
# Male      32650
# Female    16192
# Name: gender, dtype: int64

# %%
data.education.value_counts()
# Out:
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: education, dtype: int64

# %%
print(data.workclass.value_counts())
# Out:
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# ?                    2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: workclass, dtype: int64

# %%
data.occupation.replace({'?':'Others'},inplace=True)

# %%
data.occupation.value_counts()
# Out:
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# Others               2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: occupation, dtype: int64

# %%
data
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# 1      Married-civ-spouse    Farming-fishing      Husband  White    Male
# 2      Married-civ-spouse    Protective-serv      Husband  White    Male
# 3      Married-civ-spouse  Machine-op-inspct      Husband  Black    Male
# 4           Never-married             Others    Own-child  White  Female
# ...                   ...                ...          ...    ...     ...
# 48837  Married-civ-spouse       Tech-support         Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 48839             Widowed       Adm-clerical    Unmarried  White  Female
# 48840       Never-married       Adm-clerical    Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 0                 0             0              40  United-States  <=50K
# 1                 0             0              50  United-States  <=50K
# 2                 0             0              40  United-States   >50K
# 3              7688             0              40  United-States   >50K
# 4                 0             0              30  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 48837             0             0              38  United-States  <=50K
# 48838             0             0              40  United-States   >50K
# 48839             0             0              40  United-States  <=50K
# 48840             0             0              20  United-States  <=50K
# 48841         15024             0              40  United-States   >50K
#
# [48842 rows x 15 columns]

# %%
data.workclass.replace({'?':'NotListed'},inplace=True)

# %%
data.workclass.value_counts()
# Out:
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# NotListed            2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: workclass, dtype: int64

# %%
data=data[data['workclass']!='Without-pay']
data=data[data['workclass']!='Never-worked']

# %%
data.workclass.value_counts()
# Out:
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# NotListed            2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Name: workclass, dtype: int64

# %%
data.shape
# Out:
# (48811, 15)

# %%
data=data[data['education']!='5th-6th']
data=data[data['education']!='1st-4th']
data=data[data['education']!='Preschool']

# %%
data.education.value_counts()
# Out:
# HS-grad         15768
# Some-college    10873
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1809
# Assoc-acdm       1599
# 10th             1387
# 7th-8th           952
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# Name: education, dtype: int64

# %%
data.shape
# Out:
# (47972, 15)

# %%
# redundancy
data.drop(columns=['education'],inplace=True)

# %%
data
# Out:
#        age     workclass  fnlwgt  educational-num      marital-status  \
# 0       25       Private  226802                7       Never-married
# 1       38       Private   89814                9  Married-civ-spouse
# 2       28     Local-gov  336951               12  Married-civ-spouse
# 3       44       Private  160323               10  Married-civ-spouse
# 4       18     NotListed  103497               10       Never-married
# ...    ...           ...     ...              ...                 ...
# 48837   27       Private  257302               12  Married-civ-spouse
# 48838   40       Private  154374                9  Married-civ-spouse
# 48839   58       Private  151910                9             Widowed
# 48840   22       Private  201490                9       Never-married
# 48841   52  Self-emp-inc  287927                9  Married-civ-spouse
#
#               occupation relationship   race  gender  capital-gain  \
# 0      Machine-op-inspct    Own-child  Black    Male             0
# 1        Farming-fishing      Husband  White    Male             0
# 2        Protective-serv      Husband  White    Male             0
# 3      Machine-op-inspct      Husband  Black    Male          7688
# 4                 Others    Own-child  White  Female             0
# ...                  ...          ...    ...     ...           ...
# 48837       Tech-support         Wife  White  Female             0
# 48838  Machine-op-inspct      Husband  White    Male             0
# 48839       Adm-clerical    Unmarried  White  Female             0
# 48840       Adm-clerical    Own-child  White    Male             0
# 48841    Exec-managerial         Wife  White  Female         15024
#
#        capital-loss  hours-per-week native-country income
# 0                 0              40  United-States  <=50K
# 1                 0              50  United-States  <=50K
# 2                 0              40  United-States   >50K
# 3                 0              40  United-States   >50K
# 4                 0              30  United-States  <=50K
# ...             ...             ...            ...    ...
# 48837             0              38  United-States  <=50K
# 48838             0              40  United-States   >50K
# 48839             0              40  United-States  <=50K
# 48840             0              20  United-States  <=50K
# 48841             0              40  United-States   >50K
#
# [47972 rows x 14 columns]

# %%
# outlier 
plt.boxplot(data['age'])
plt.show()

# %%
data = data[(data['age']<=75)& (data['age']>=17)]

# %%
plt.boxplot(data['age'])
plt.show()

# %%
# x=data.drop(columns=['income'])
# y = data['income']
# x

# %%
# label encoding
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
data['workclass'] = encoder.fit_transform(data['workclass'])
data['marital-status']  = encoder.fit_transform(data['marital-status'])
data['occupation']  = encoder.fit_transform(data['occupation'])
data['relationship'] = encoder.fit_transform(data['relationship'])
data['race']  = encoder.fit_transform(data['race'])
data['gender']  = encoder.fit_transform(data['gender'])
data['native-country'] = encoder.fit_transform(data['native-country'])
# data['']
# Out:
# C:\Users\KALLY\AppData\Local\Temp\ipykernel_12196\35541391.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['workclass'] = encoder.fit_transform(data['workclass'])
# C:\Users\KALLY\AppData\Local\Temp\ipykernel_12196\35541391.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['marital-status']  = encoder.fit_transform(data['marital-status'])
# C:\Users\KALLY\AppData\Local\Temp\ipykernel_12196\35541391.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['occupation']  = encoder.fit_transform(data['occupation'])
# C:\Users\KALLY\AppData\Local\Temp\ipykernel_12196\35541391.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['relationship'] = encoder.fit_transform(data['relationship'])
# C:\Users\KALLY\AppData\Local\Temp\ipykernel_12196\35541391.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['race']  = encoder.fit_transform(data['race'])
# C:\Users\KALLY\AppData\Local\Temp\ipykernel_12196\35541391.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['gender']  = encoder.fit_transform(data['gender'])
# C:\Users\KALLY\AppData\Local\Temp\ipykernel_12196\35541391.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['native-country'] = encoder.fit_transform(data['native-country'])

# %%
data
# Out:
#        age  workclass  fnlwgt  educational-num  marital-status  occupation  \
# 0       25          3  226802                7               4           6
# 1       38          3   89814                9               2           4
# 2       28          1  336951               12               2          11
# 3       44          3  160323               10               2           6
# 4       18          2  103497               10               4           8
# ...    ...        ...     ...              ...             ...         ...
# 48837   27          3  257302               12               2          13
# 48838   40          3  154374                9               2           6
# 48839   58          3  151910                9               6           0
# 48840   22          3  201490                9               4           0
# 48841   52          4  287927                9               2           3
#
#        relationship  race  gender  capital-gain  capital-loss  hours-per-week  \
# 0                 3     2       1             0             0              40
# 1                 0     4       1             0             0              50
# 2                 0     4       1             0             0              40
# 3                 0     2       1          7688             0              40
# 4                 3     4       0             0             0              30
# ...             ...   ...     ...           ...           ...             ...
# 48837             5     4       0             0             0              38
# 48838             0     4       1             0             0              40
# 48839             4     4       0             0             0              40
# 48840             3     4       1             0             0              20
# 48841             5     4       0         15024             0              40
#
#        native-country income
# 0                  39  <=50K
# 1                  39  <=50K
# 2                  39   >50K
# 3                  39   >50K
# 4                  39  <=50K
# ...               ...    ...
# 48837              39  <=50K
# 48838              39   >50K
# 48839              39  <=50K
# 48840              39  <=50K
# 48841              39   >50K
#
# [47619 rows x 14 columns]

# %%
x=data.drop(columns=['income'])
y=data['income']

# %%
x
# Out:
#        age  workclass  fnlwgt  educational-num  marital-status  occupation  \
# 0       25          3  226802                7               4           6
# 1       38          3   89814                9               2           4
# 2       28          1  336951               12               2          11
# 3       44          3  160323               10               2           6
# 4       18          2  103497               10               4           8
# ...    ...        ...     ...              ...             ...         ...
# 48837   27          3  257302               12               2          13
# 48838   40          3  154374                9               2           6
# 48839   58          3  151910                9               6           0
# 48840   22          3  201490                9               4           0
# 48841   52          4  287927                9               2           3
#
#        relationship  race  gender  capital-gain  capital-loss  hours-per-week  \
# 0                 3     2       1             0             0              40
# 1                 0     4       1             0             0              50
# 2                 0     4       1             0             0              40
# 3                 0     2       1          7688             0              40
# 4                 3     4       0             0             0              30
# ...             ...   ...     ...           ...           ...             ...
# 48837             5     4       0             0             0              38
# 48838             0     4       1             0             0              40
# 48839             4     4       0             0             0              40
# 48840             3     4       1             0             0              20
# 48841             5     4       0         15024             0              40
#
#        native-country
# 0                  39
# 1                  39
# 2                  39
# 3                  39
# 4                  39
# ...               ...
# 48837              39
# 48838              39
# 48839              39
# 48840              39
# 48841              39
#
# [47619 rows x 13 columns]

# %%
y
# Out:
# 0        <=50K
# 1        <=50K
# 2         >50K
# 3         >50K
# 4        <=50K
#          ...
# 48837    <=50K
# 48838     >50K
# 48839    <=50K
# 48840    <=50K
# 48841     >50K
# Name: income, Length: 47619, dtype: object

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x = scaler.fit_transform(x)
x
# Out:
# array([[0.13793103, 0.5       , 0.14512876, ..., 0.        , 0.39795918,
#         0.95121951],
#        [0.36206897, 0.5       , 0.05245126, ..., 0.        , 0.5       ,
#         0.95121951],
#        [0.18965517, 0.16666667, 0.21964867, ..., 0.        , 0.39795918,
#         0.95121951],
#        ...,
#        [0.70689655, 0.5       , 0.09446153, ..., 0.        , 0.39795918,
#         0.95121951],
#        [0.0862069 , 0.5       , 0.12800425, ..., 0.        , 0.19387755,
#         0.95121951],
#        [0.60344828, 0.66666667, 0.18648211, ..., 0.        , 0.39795918,
#         0.95121951]])

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2, random_state=23, stratify=y)

# %%
xtrain
# Out:
# array([[0.44827586, 0.5       , 0.10248458, ..., 0.        , 0.39795918,
#         0.95121951],
#        [0.17241379, 0.16666667, 0.08567128, ..., 0.        , 0.34693878,
#         0.95121951],
#        [0.75862069, 0.83333333, 0.11752469, ..., 0.        , 0.39795918,
#         0.04878049],
#        ...,
#        [0.0862069 , 0.66666667, 0.24567574, ..., 0.        , 0.39795918,
#         0.85365854],
#        [0.53448276, 0.5       , 0.14505705, ..., 0.        , 0.39795918,
#         0.95121951],
#        [0.01724138, 0.5       , 0.0515217 , ..., 0.        , 0.35714286,
#         0.95121951]])

# %%
#machine learning
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(xtrain,ytrain)  # input and output training data
predict = knn.predict(xtest)
predict
# Out:
# array(['<=50K', '<=50K', '>50K', ..., '<=50K', '<=50K', '<=50K'],
#       dtype=object)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(ytest,predict)
# Out:
# 0.8167786644267114

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(xtrain,ytrain)  # input and output training data
predict1 = lr.predict(xtest)
predict1
# Out:
# array(['<=50K', '<=50K', '>50K', ..., '<=50K', '<=50K', '<=50K'],
#       dtype=object)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(ytest,predict1)
# Out:
# 0.8201385972280555

# %%
from sklearn.neural_network import MLPClassifier
clf = MLPClassifier(solver='adam',hidden_layer_sizes=(5,2),random_state=2,max_iter=2000)
clf.fit(xtrain,ytrain)
predict2 = clf.predict(xtest)
predict2
# Out:
# array(['<=50K', '<=50K', '>50K', ..., '<=50K', '<=50K', '<=50K'],
#       dtype='<U5')

# %%
from sklearn.metrics import accuracy_score
accuracy_score(ytest,predict2)
# Out:
# 0.8391432171356573

# %%
#Employee salary predictions using ai,ml algm
# use streamlit for frontend development

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler, OneHotEncoder

X_train, X_test, y_train, y_test =  train_test_split(x,y,random_state=42,test_size=0.2)

models = {
    "LogiasticRegression": LogisticRegression(),
    "RandomForest": RandomForestClassifier(),
    "SVM": SVC(),
    "GradientBoosting": GradientBoostingClassifier()
}
result = {}

for name, model in models.items():
    pipe = Pipeline([
        ('scaler', StandardScaler()),
        ('model',model)
    ])
    pipe.fit(X_train, y_train)
    y_pred = pipe.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    result[name] = acc
    print(f"{name} Accuracy: {acc:.4f}")
    print(classification_report(y_test, y_pred))
# Out:
# LogiasticRegression Accuracy: 0.8291
#               precision    recall  f1-score   support
#
#        <=50K       0.85      0.94      0.89      7277
#         >50K       0.71      0.47      0.56      2247
#
#     accuracy                           0.83      9524
#    macro avg       0.78      0.70      0.73      9524
# weighted avg       0.82      0.83      0.82      9524
#
# RandomForest Accuracy: 0.8662
#               precision    recall  f1-score   support
#
#        <=50K       0.90      0.93      0.91      7277
#         >50K       0.75      0.65      0.70      2247
#
#     accuracy                           0.87      9524
#    macro avg       0.82      0.79      0.81      9524
# weighted avg       0.86      0.87      0.86      9524
#
# SVM Accuracy: 0.8566
#               precision    recall  f1-score   support
#
#        <=50K       0.88      0.94      0.91      7277
#         >50K       0.76      0.57      0.65      2247
#
#     accuracy                           0.86      9524
#    macro avg       0.82      0.76      0.78      9524
# weighted avg       0.85      0.86      0.85      9524
#
# GradientBoosting Accuracy: 0.8711
#               precision    recall  f1-score   support
#
#        <=50K       0.89      0.95      0.92      7277
#         >50K       0.79      0.62      0.69      2247
#
#     accuracy                           0.87      9524
#    macro avg       0.84      0.78      0.81      9524
# weighted avg       0.87      0.87      0.87      9524

# %%
#Get best model
import joblib
best_model_name = max(result, key = result.get)
best_model = models[best_model_name]
print(f"\n Best model: {best_model_name} with accuracy {result[best_model_name]:4f}")

# Save the best model
joblib.dump(best_model, "best_model.pkl")
print("Saved best model as best_model.pkl")
# Out:
#  Best model: GradientBoosting with accuracy 0.871063
# Saved best model as best_model.pkl

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[112], line 7
#       4 joblib.dump(best_model, "best_model.pkl")
#       5 joblib.dump(scaler, "scaler.pkl")
# ----> 7 joblib.dump(discrete_encoders, "encoders.pkl")
#
# NameError: name 'discrete_encoders' is not defined

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd
import joblib  # Needed to load the model

# Load the trained model
model = joblib.load("best_model.pkl")

st.set_page_config(page_title="Employee Salary Prediction", page_icon="🧑‍💼", layout="centered")
st.title("🧑‍💼 Employee Salary Prediction App")
st.markdown("Use this app to predict whether an employee earns >50K or <=50K based on input features.")

# Sidebar for user input
st.sidebar.header("Enter Employee Details:")

age = st.sidebar.slider("Age", 18, 65, 30)
education = st.sidebar.selectbox("Education Level", ["Bachelors", "Masters", "PhD", "HS-grad", "Assoc", "Some-college"])
occupation = st.sidebar.selectbox("Job Role", [
    "Tech-support", "Craft-repair", "Other-service", "Sales", "Exec-managerial",
    "Prof-specialty", "Handlers-cleaners", "Machine-op-inspect", "Adm-clerical",
    "Farming-fishing", "Transport-moving", "Priv-house-serv", "Protective-serv", "Armed-Forces"
])
hours_per_week = st.sidebar.slider("Hours per Week", 1, 80, 40)
experience = st.sidebar.slider("Years of Experience", 0, 40, 5)

# Prepare input DataFrame (must match model training format)
input_df = pd.DataFrame({
    "age": [age],
    "education": [education],
    "occupation": [occupation],
    "hours-per-week": [hours_per_week],
    "experience": [experience],
})

st.write("### 🧾 Input Data")
st.dataframe(input_df)

# Predict button
if st.button("🔍 Predict Salary Class"):
    prediction = model.predict(input_df)
    st.success(f"💼 Predicted Salary Class: {prediction[0]}")

# Batch Prediction Section
st.markdown("---")
st.markdown("## 📂 Batch Prediction from CSV")
uploaded_file = st.file_uploader("Upload a CSV file", type="csv")

if uploaded_file is not None:
    batch_data = pd.read_csv(uploaded_file)
    st.write("📋 Uploaded Data Preview")
    st.dataframe(batch_data.head())
    
    # Make predictions
    batch_preds = model.predict(batch_data)
    batch_data["PredictedClass"] = batch_preds
    
    st.write("🧠 Predictions:")
    st.dataframe(batch_data.head())
    
    csv = batch_data.to_csv(index=False).encode('utf-8')
    st.download_button("⬇️ Download Predictions CSV", data=csv, file_name='predicted_classes.csv', mime='text/csv')
# Out:
# Overwriting app.py

# %%
# !pip install streamlit pyngrok
# Out:
# Requirement already satisfied: streamlit in c:\users\kally\anaconda3\lib\site-packages (1.47.0)
# Requirement already satisfied: pyngrok in c:\users\kally\anaconda3\lib\site-packages (7.2.12)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\kally\anaconda3\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\kally\anaconda3\lib\site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\kally\anaconda3\lib\site-packages (from streamlit) (2.28.1)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\kally\anaconda3\lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\kally\anaconda3\lib\site-packages (from streamlit) (5.29.4)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\kally\anaconda3\lib\site-packages (from streamlit) (2.1.6)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\kally\anaconda3\lib\site-packages (from streamlit) (21.0.0)
# Requirement already satisfied: packaging<26,>=20 in c:\users\kally\anaconda3\lib\site-packages (from streamlit) (22.0)
# Requirement already satisfied: click<9,>=7.0 in c:\users\kally\anaconda3\lib\site-packages (from streamlit) (8.0.4)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\kally\anaconda3\lib\site-packages (from streamlit) (10.3.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\kally\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\kally\anaconda3\lib\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\kally\anaconda3\lib\site-packages (from streamlit) (4.13.2)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\kally\anaconda3\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\kally\anaconda3\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\kally\anaconda3\lib\site-packages (from streamlit) (3.1.44)
# Requirement already satisfied: cachetools<7,>=4.0 in c:\users\kally\anaconda3\lib\site-packages (from streamlit) (6.1.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\kally\anaconda3\lib\site-packages (from streamlit) (1.5.3)
# Requirement already satisfied: PyYAML>=5.1 in c:\users\kally\anaconda3\lib\site-packages (from pyngrok) (6.0)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\kally\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (4.19.2)
# Requirement already satisfied: jinja2 in c:\users\kally\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\kally\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (1.48.0)
# Requirement already satisfied: colorama in c:\users\kally\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\kally\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\kally\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kally\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2022.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\kally\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\kally\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kally\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kally\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2024.7.4)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\kally\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kally\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\kally\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\kally\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\kally\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.6)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\kally\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\kally\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas<3,>=1.4.0->streamlit) (1.16.0)

# %%
# Out:
# Found existing installation: pyngrok 7.2.12Note: you may need to restart the kernel to use updated packages.
#
# Uninstalling pyngrok-7.2.12:
#   Successfully uninstalled pyngrok-7.2.12

# %%
pip install pyngrok --upgrade
# Out:
# Collecting pyngrok
#   Using cached pyngrok-7.2.12-py3-none-any.whl (26 kB)
# Requirement already satisfied: PyYAML>=5.1 in c:\users\kally\anaconda3\lib\site-packages (from pyngrok) (6.0)
# Installing collected packages: pyngrok
# Successfully installed pyngrok-7.2.12
# Note: you may need to restart the kernel to use updated packages.

# %%
# !ngrok config add-authtoken 30EErT9rfYQMcCji5Si1jD7yctP_6Cw3pMitayZi3cG1HFKov
# Out:
# Downloading ngrok ...
# Downloading ngrok: 0%
# Downloading ngrok: 1%
# Downloading ngrok: 2%
# Downloading ngrok: 3%
# Downloading ngrok: 4%
# Downloading ngrok: 5%
# Downloading ngrok: 6%
# Downloading ngrok: 7%
# Downloading ngrok: 8%
# Downloading ngrok: 9%
# Downloading ngrok: 10%
# Downloading ngrok: 11%
# Downloading ngrok: 12%
# Downloading ngrok: 13%
# Downloading ngrok: 14%
# Downloading ngrok: 15%
# Downloading ngrok: 16%
# Downloading ngrok: 17%
# Downloading ngrok: 18%
# Downloading ngrok: 19%
# Downloading ngrok: 20%
# Downloading ngrok: 21%
# Downloading ngrok: 22%
# Downloading ngrok: 23%
# Downloading ngrok: 24%
# Downloading ngrok: 25%
# Downloading ngrok: 26%
# Downloading ngrok: 27%
# Downloading ngrok: 28%
# Downloading ngrok: 29%
# Downloading ngrok: 30%
# Downloading ngrok: 31%
# Downloading ngrok: 32%
# Downloading ngrok: 33%
# Downloading ngrok: 34%
# Downloading ngrok: 35%
# Downloading ngrok: 36%
# Downloading ngrok: 37%
# Downloading ngrok: 38%
# Downloading ngrok: 39%
# Downloading ngrok: 40%
# Downloading ngrok: 41%
# Downloading ngrok: 42%
# Downloading ngrok: 43%
# Downloading ngrok: 44%
# Downloading ngrok: 45%
# Downloading ngrok: 46%
# Downloading ngrok: 47%
# Downloading ngrok: 48%
# Downloading ngrok: 49%
# Downloading ngrok: 50%
# Downloading ngrok: 51%
# Downloading ngrok: 52%
# Downloading ngrok: 53%
# Downloading ngrok: 54%
# Downloading ngrok: 55%
# Downloading ngrok: 56%
# Downloading ngrok: 57%
# Downloading ngrok: 58%
# Downloading ngrok: 59%
# Downloading ngrok: 60%
# Downloading ngrok: 61%
# Downloading ngrok: 62%
# Downloading ngrok: 63%
# Downloading ngrok: 64%
# Downloading ngrok: 65%
# Downloading ngrok: 66%
# Downloading ngrok: 67%
# Downloading ngrok: 68%
# Downloading ngrok: 69%
# Downloading ngrok: 70%
# Downloading ngrok: 71%
# Downloading ngrok: 72%
# Downloading ngrok: 73%
# Downloading ngrok: 74%
# Downloading ngrok: 75%
# Downloading ngrok: 76%
# Downloading ngrok: 77%
# Downloading ngrok: 78%
# Downloading ngrok: 79%
# Downloading ngrok: 80%
# Downloading ngrok: 81%
# Downloading ngrok: 82%
# Downloading ngrok: 83%
# Downloading ngrok: 84%
# Downloading ngrok: 85%
# Downloading ngrok: 86%
# Downloading ngrok: 87%
# Downloading ngrok: 88%
# Downloading ngrok: 89%
# Downloading ngrok: 90%
# Downloading ngrok: 91%
# Downloading ngrok: 92%
# Downloading ngrok: 93%
# Downloading ngrok: 94%
# Downloading ngrok: 95%
# Downloading ngrok: 96%
# Downloading ngrok: 97%
# Downloading ngrok: 98%
# Downloading ngrok: 99%
# Downloading ngrok: 100%
#
# Installing ngrok ...
# Traceback (most recent call last):
#   File "C:\Users\KALLY\anaconda3\lib\site-packages\pyngrok\installer.py", line 192, in install_ngrok
#     _install_ngrok_zip(ngrok_path, download_path)
#   File "C:\Users\KALLY\anaconda3\lib\site-packages\pyngrok\installer.py", line 207, in _install_ngrok_zip
#     with zipfile.ZipFile(zip_path, "r") as zip_ref:
#   File "C:\Users\KALLY\anaconda3\lib\zipfile.py", line 1249, in __init__
#     self.fp = io.open(file, filemode)
# OSError: [Errno 22] Invalid argument: 'C:\\Users\\KALLY\\AppData\\Local\\Temp\\ngrok-v3-stable-windows-amd64.zip'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\KALLY\anaconda3\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\KALLY\anaconda3\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\KALLY\anaconda3\Scripts\ngrok.exe\__main__.py", line 7, in <module>
#   File "C:\Users\KALLY\anaconda3\lib\site-packages\pyngrok\ngrok.py", line 687, in main
#     run(sys.argv[1:])
#   File "C:\Users\KALLY\anaconda3\lib\site-packages\pyngrok\ngrok.py", line 673, in run
#     install_ngrok(pyngrok_config)
#   File "C:\Users\KALLY\anaconda3\lib\site-packages\pyngrok\ngrok.py", line 129, in install_ngrok
#     installer.install_ngrok(pyngrok_config.ngrok_path, ngrok_version=pyngrok_config.ngrok_version)
#   File "C:\Users\KALLY\anaconda3\lib\site-packages\pyngrok\installer.py", line 194, in install_ngrok
#     raise PyngrokNgrokInstallError(f"An error occurred while downloading ngrok from {url}: {e}")
# pyngrok.exception.PyngrokNgrokInstallError: An error occurred while downloading ngrok from https://bin.equinox.io/c/bNyj1mQVY4c/ngrok-v3-stable-windows-amd64.zip: [Errno 22] Invalid argument: 'C:\\Users\\KALLY\\AppData\\Local\\Temp\\ngrok-v3-stable-windows-amd64.zip'

# %%
import os
import threading 
def run_streamlit():
    os.system('streamlit run app.py --server.port 8501')
    
thread = threading.Thread(target=run_streamlit)
thread.start()

# %%
from pyngrok import ngrok
import time

time.sleep(5)
public_url = ngrok.connect(8501)
print("Your streamlit app is live here:",public_url)
# Out:
# Installing ngrok ...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pyngrok\installer.py:192, in install_ngrok(ngrok_path, ngrok_version, **kwargs)
#     190     download_path = _download_file(url, **kwargs)
# --> 192     _install_ngrok_zip(ngrok_path, download_path)
#     193 except Exception as e:
#
# File ~\anaconda3\lib\site-packages\pyngrok\installer.py:207, in _install_ngrok_zip(ngrok_path, zip_path)
#     205 _print_progress("Installing ngrok ... ")
# --> 207 with zipfile.ZipFile(zip_path, "r") as zip_ref:
#     208     logger.debug(f"Extracting ngrok binary from {zip_path} to {ngrok_path} ...")
#
# File ~\anaconda3\lib\zipfile.py:1249, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1248 try:
# -> 1249     self.fp = io.open(file, filemode)
#    1250 except OSError:
#
# OSError: [Errno 22] Invalid argument: 'C:\\Users\\KALLY\\AppData\\Local\\Temp\\ngrok-v3-stable-windows-amd64.zip'
#
# During handling of the above exception, another exception occurred:
#
# PyngrokNgrokInstallError                  Traceback (most recent call last)
# Cell In[107], line 5
#       2 import time
#       4 time.sleep(5)
# ----> 5 public_url = ngrok.connect(8501)
#       6 print("Your streamlit app is live here:",public_url)
#
# File ~\anaconda3\lib\site-packages\pyngrok\ngrok.py:385, in connect(addr, proto, name, pyngrok_config, **options)
#     381 _upgrade_legacy_params(pyngrok_config, options)
#     383 logger.info(f"Opening tunnel named: {name}")
# --> 385 api_url = get_ngrok_process(pyngrok_config).api_url
#     387 logger.debug(f"Creating tunnel with options: {options}")
#     389 tunnel = NgrokTunnel(api_request(f"{api_url}/api/tunnels", method="POST", data=options,
#     390                                  timeout=pyngrok_config.request_timeout),
#     391                      pyngrok_config, api_url)
#
# File ~\anaconda3\lib\site-packages\pyngrok\ngrok.py:201, in get_ngrok_process(pyngrok_config)
#     198 if pyngrok_config is None:
#     199     pyngrok_config = conf.get_default()
# --> 201 install_ngrok(pyngrok_config)
#     203 return process.get_process(pyngrok_config)
#
# File ~\anaconda3\lib\site-packages\pyngrok\ngrok.py:129, in install_ngrok(pyngrok_config)
#     126     pyngrok_config = conf.get_default()
#     128 if not os.path.exists(pyngrok_config.ngrok_path):
# --> 129     installer.install_ngrok(pyngrok_config.ngrok_path, ngrok_version=pyngrok_config.ngrok_version)
#     131 config_path = conf.get_config_path(pyngrok_config)
#     133 # Install the config to the requested path
#
# File ~\anaconda3\lib\site-packages\pyngrok\installer.py:194, in install_ngrok(ngrok_path, ngrok_version, **kwargs)
#     192     _install_ngrok_zip(ngrok_path, download_path)
#     193 except Exception as e:
# --> 194     raise PyngrokNgrokInstallError(f"An error occurred while downloading ngrok from {url}: {e}")
#
# PyngrokNgrokInstallError: An error occurred while downloading ngrok from https://bin.equinox.io/c/bNyj1mQVY4c/ngrok-v3-stable-windows-amd64.zip: [Errno 22] Invalid argument: 'C:\\Users\\KALLY\\AppData\\Local\\Temp\\ngrok-v3-stable-windows-amd64.zip'

# %%
import os, threading
from pyngrok import ngrok
import time

def run_streamlit():
    os.system("streamlit run app.py --server.port 8501")

thread = threading.Thread(target=run_streamlit, daemon=True)
thread.start()

time.sleep(5)  # Wait for app to start
public_url = ngrok.connect(8501)
print("🌍 Public URL:", public_url)
# Out:
# Installing ngrok ...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pyngrok\installer.py:192, in install_ngrok(ngrok_path, ngrok_version, **kwargs)
#     190     download_path = _download_file(url, **kwargs)
# --> 192     _install_ngrok_zip(ngrok_path, download_path)
#     193 except Exception as e:
#
# File ~\anaconda3\lib\site-packages\pyngrok\installer.py:207, in _install_ngrok_zip(ngrok_path, zip_path)
#     205 _print_progress("Installing ngrok ... ")
# --> 207 with zipfile.ZipFile(zip_path, "r") as zip_ref:
#     208     logger.debug(f"Extracting ngrok binary from {zip_path} to {ngrok_path} ...")
#
# File ~\anaconda3\lib\zipfile.py:1249, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1248 try:
# -> 1249     self.fp = io.open(file, filemode)
#    1250 except OSError:
#
# OSError: [Errno 22] Invalid argument: 'C:\\Users\\KALLY\\AppData\\Local\\Temp\\ngrok-v3-stable-windows-amd64.zip'
#
# During handling of the above exception, another exception occurred:
#
# PyngrokNgrokInstallError                  Traceback (most recent call last)
# Cell In[108], line 12
#       9 thread.start()
#      11 time.sleep(5)  # Wait for app to start
# ---> 12 public_url = ngrok.connect(8501)
#      13 print("🌍 Public URL:", public_url)
#
# File ~\anaconda3\lib\site-packages\pyngrok\ngrok.py:385, in connect(addr, proto, name, pyngrok_config, **options)
#     381 _upgrade_legacy_params(pyngrok_config, options)
#     383 logger.info(f"Opening tunnel named: {name}")
# --> 385 api_url = get_ngrok_process(pyngrok_config).api_url
#     387 logger.debug(f"Creating tunnel with options: {options}")
#     389 tunnel = NgrokTunnel(api_request(f"{api_url}/api/tunnels", method="POST", data=options,
#     390                                  timeout=pyngrok_config.request_timeout),
#     391                      pyngrok_config, api_url)
#
# File ~\anaconda3\lib\site-packages\pyngrok\ngrok.py:201, in get_ngrok_process(pyngrok_config)
#     198 if pyngrok_config is None:
#     199     pyngrok_config = conf.get_default()
# --> 201 install_ngrok(pyngrok_config)
#     203 return process.get_process(pyngrok_config)
#
# File ~\anaconda3\lib\site-packages\pyngrok\ngrok.py:129, in install_ngrok(pyngrok_config)
#     126     pyngrok_config = conf.get_default()
#     128 if not os.path.exists(pyngrok_config.ngrok_path):
# --> 129     installer.install_ngrok(pyngrok_config.ngrok_path, ngrok_version=pyngrok_config.ngrok_version)
#     131 config_path = conf.get_config_path(pyngrok_config)
#     133 # Install the config to the requested path
#
# File ~\anaconda3\lib\site-packages\pyngrok\installer.py:194, in install_ngrok(ngrok_path, ngrok_version, **kwargs)
#     192     _install_ngrok_zip(ngrok_path, download_path)
#     193 except Exception as e:
# --> 194     raise PyngrokNgrokInstallError(f"An error occurred while downloading ngrok from {url}: {e}")
#
# PyngrokNgrokInstallError: An error occurred while downloading ngrok from https://bin.equinox.io/c/bNyj1mQVY4c/ngrok-v3-stable-windows-amd64.zip: [Errno 22] Invalid argument: 'C:\\Users\\KALLY\\AppData\\Local\\Temp\\ngrok-v3-stable-windows-amd64.zip'
